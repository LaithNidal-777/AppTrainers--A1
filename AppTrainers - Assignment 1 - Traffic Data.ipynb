# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

from scipy import stats

# %%
df = pd.read_csv(r"C:\Users\User\Desktop\App Trainers Assignment 1\traffic.csv")
df.head()
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        31          0         4
# 1  12:15:00 AM    10         Tuesday        49          0         3
# 2  12:30:00 AM    10         Tuesday        46          0         3
# 3  12:45:00 AM    10         Tuesday        51          0         2
# 4   1:00:00 AM    10         Tuesday        57          6        15
#
#    TruckCount  Total Traffic Situation
# 0           4     39               low
# 1           3     55               low
# 2           6     55               low
# 3           5     58               low
# 4          16     94            normal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2976 entries, 0 to 2975
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               2976 non-null   object
#  1   Date               2976 non-null   int64
#  2   Day of the week    2976 non-null   object
#  3   CarCount           2976 non-null   int64
#  4   BikeCount          2976 non-null   int64
#  5   BusCount           2976 non-null   int64
#  6   TruckCount         2976 non-null   int64
#  7   Total              2976 non-null   int64
#  8   Traffic Situation  2976 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 209.4+ KB

# %%
df.describe()
# Out:
#               Date     CarCount    BikeCount     BusCount   TruckCount  \
# count  2976.000000  2976.000000  2976.000000  2976.000000  2976.000000
# mean     16.000000    68.696573    14.917339    15.279570    15.324933
# std       8.945775    45.850693    12.847518    14.341986    10.603833
# min       1.000000     6.000000     0.000000     0.000000     0.000000
# 25%       8.000000    19.000000     5.000000     1.000000     6.000000
# 50%      16.000000    64.000000    12.000000    12.000000    14.000000
# 75%      24.000000   107.000000    22.000000    25.000000    23.000000
# max      31.000000   180.000000    70.000000    50.000000    40.000000
#
#              Total
# count  2976.000000
# mean    114.218414
# std      60.190627
# min      21.000000
# 25%      55.000000
# 50%     109.000000
# 75%     164.000000
# max     279.000000

# %%
df.columns
# Out:
# Index(['Time', 'Date', 'Day of the week', 'CarCount', 'BikeCount', 'BusCount',
#        'TruckCount', 'Total', 'Traffic Situation'],
#       dtype='object')

# %% [markdown]
# ### 1. Vehicle Distribution Analysis

# %%
sns.histplot(df['CarCount'] ,kde= True, bins = 20)

# Get the fitted parameters used by the function
(mu, sigma) = stats.norm.fit(df['CarCount'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Car Count distribution')
# Out:
#  mu = 68.70 and sigma = 45.84
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\User\AppData\Local\Temp\ipykernel_26116\2410679517.py:8: SyntaxWarning: invalid escape sequence '\m'
#   plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
# Text(0.5, 1.0, 'Car Count distribution')

# %%
sns.histplot(df['BikeCount'] ,kde= True, bins = 20)

# Get the fitted parameters used by the function
(mu, sigma) = stats.norm.fit(df['BikeCount'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Bike Count distribution')
# Out:
#  mu = 14.92 and sigma = 12.85
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\User\AppData\Local\Temp\ipykernel_26116\3746030898.py:8: SyntaxWarning: invalid escape sequence '\m'
#   plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
# Text(0.5, 1.0, 'Bike Count distribution')

# %%
sns.histplot(df['BusCount'] ,kde= True, bins = 20)

# Get the fitted parameters used by the function
(mu, sigma) = stats.norm.fit(df['BusCount'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Bus Count distribution')
# Out:
#  mu = 15.28 and sigma = 14.34
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\User\AppData\Local\Temp\ipykernel_26116\2032236669.py:8: SyntaxWarning: invalid escape sequence '\m'
#   plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
# Text(0.5, 1.0, 'Bus Count distribution')

# %%
sns.histplot(df['TruckCount'] ,kde= True, bins = 20)

# Get the fitted parameters used by the function
(mu, sigma) = stats.norm.fit(df['TruckCount'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Truck Count distribution')
# Out:
#  mu = 15.32 and sigma = 10.60
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\User\AppData\Local\Temp\ipykernel_26116\1929670189.py:8: SyntaxWarning: invalid escape sequence '\m'
#   plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
# Text(0.5, 1.0, 'Truck Count distribution')

# %% [markdown]
# ### 2. Traffic Situation Distribution

# %%
tf = df['Traffic Situation'].value_counts()
tf.plot(kind = 'pie',label = 'Traffic Situation', autopct="%1.2f%%", title = "Distribution by Traffic Situation")
# Out:
# <Axes: title={'center': 'Distribution by Traffic Situation'}, ylabel='Traffic Situation'>

# %% [markdown]
# ### 3. Vehicle Count Variation by Day of the Week

# %%
dow_count = df.loc[:, ['CarCount','BikeCount','BusCount','TruckCount','Total', 'Day of the week']].groupby('Day of the week').sum().reset_index()
dow_count_chart = dow_count.plot(kind = 'bar', x = 'Day of the week', y = 'CarCount', stacked = True, xlabel= 'Day of the week', ylabel = 'Count ', title = 'Car Count Variation by Day of Week')

# %%
dow_count = df.loc[:, ['CarCount','BikeCount','BusCount','TruckCount','Total', 'Day of the week']].groupby('Day of the week').sum().reset_index()
dow_count_chart = dow_count.plot(kind = 'bar', x = 'Day of the week', y = 'BikeCount', stacked = True, xlabel= 'Day of the week', ylabel = 'Count ', title = 'Bike Count Variation by Day of Week')

# %%
dow_count = df.loc[:, ['CarCount','BikeCount','BusCount','TruckCount','Total', 'Day of the week']].groupby('Day of the week').sum().reset_index()
dow_count_chart = dow_count.plot(kind = 'bar', x = 'Day of the week', y = 'BusCount', stacked = True, xlabel= 'Day of the week', ylabel = 'Count ', title = 'Bus Count Variation by Day of Week')

# %%
dow_count = df.loc[:, ['CarCount','BikeCount','BusCount','TruckCount','Total', 'Day of the week']].groupby('Day of the week').sum().reset_index()
dow_count_chart = dow_count.plot(kind = 'bar', x = 'Day of the week', y = 'TruckCount', stacked = True, xlabel= 'Day of the week', ylabel = 'Count ', title = 'Truck Count Variation by Day of Week')

# %% [markdown]
# ### 4 Car count vs. Traffic Situation

# %%
ts_car_count = df.loc[:,['CarCount', 'Traffic Situation']]
ts_car_count.chart = ts_car_count.plot(kind = 'scatter', x = 'Traffic Situation', y = 'CarCount', xlabel= 'Traffic Situation', ylabel = 'Car Count', title = ' Relationship between Car Count and Traffic Situation')

# %% [markdown]
# ### 5 . Bike Count vs Traffic Situation

# %%
ts_bike_count = df.loc[:,['BikeCount', 'Traffic Situation']]
ts_bike_count.chart = ts_bike_count.plot(kind = 'scatter', x = 'Traffic Situation', y = 'BikeCount', xlabel= 'Traffic Situation', ylabel = 'Car Count', title = ' Relationship between Bike Count and Traffic Situation')

# %% [markdown]
# ### 6. Bus Count vs Traffic Situation

# %%
ts_bus_count = df.loc[:,['BusCount', 'Traffic Situation']]
ts_bus_count.chart = ts_bus_count.plot(kind = 'scatter', x = 'Traffic Situation', y = 'BusCount', xlabel= 'Traffic Situation', ylabel = 'Bus Count', title = ' Relationship between Bus Count and Traffic Situation')

# %% [markdown]
# ### 7. Truck Count vs. Traffic Situation

# %%
ts_truck_count = df.loc[:,['TruckCount', 'Traffic Situation']]
ts_truck_count.chart = ts_truck_count.plot(kind = 'scatter', x = 'Traffic Situation', y = 'TruckCount', xlabel= 'Traffic Situation', ylabel = 'Truck Count', title = ' Relationship between Truck Count and Traffic Situation')

# %% [markdown]
# ### 8. Total Vehicle Count by Traffic Situation

# %%
ts_total_count = df.loc[:,['Total', 'Traffic Situation']]
ts_total_count_chart = ts_total_count.plot(kind = 'scatter', x = 'Traffic Situation', y = 'Total', xlabel= 'Traffic Situation', ylabel = 'Car Count', title = ' Relationship between Total Count and Traffic Situation')

# %% [markdown]
# #### 9. Busiest Hours of the Day

# %%
df['Time'] = pd.to_datetime(df['Time'], format = "%I:%M:%S %p")
df['Hour'] = df['Time'].dt.hour

#Defining bins for hourly grouping 

hour_bins = list(range(0,25,1))
hour_labels = [f"{h}:00 - {h+1}:00" for h in range(24)]

#Apply pd.cut to categorize hours
df['Hour Group'] = pd.cut(df['Hour'], bins = hour_bins, labels = hour_labels, right = False)
hourly_traffic = df.groupby("Hour Group")['Total'].sum()

hourly_traffic.plot(kind = 'bar', x = 'Hour Group', y= 'Total', title = 'Busiest Hours of Day', xlabel='Hour Group', ylabel = 'Total Count')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_26116\3002875469.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hourly_traffic = df.groupby("Hour Group")['Total'].sum()
# <Axes: title={'center': 'Busiest Hours of Day'}, xlabel='Hour Group', ylabel='Total Count'>
